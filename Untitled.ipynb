# %%
f = open("Marvel.txt", "r")
print(f.read())
f.close()
# Out:
# Jubal
# Trump
# Tasha
# Emmanuel
# Paul
# David
# Favour

# %%
f = open("Marvel.txt", "r")
print(f.readline())

print(f.readline())
# Out:
# Jubal
#
# Trump

# %%
for line in f:
    print(line)
# Out:
# Tasha
#
# Emmanuel
#
# Paul
#
# David
#
# Favour

# %%
f = open("Marvel.txt", "r")
for line in f:
    print(line)
# Out:
# Jubal
#
# Trump
#
# Tasha
#
# Emmanuel
#
# Paul
#
# David
#
# Favour

# %%
f = open("Marvel.txt", "a")
f.write("\nChristian")
f.close()

# %%
f = open("Marvel.txt")
print(f.read())
# Out:
# Jubal
# Trump
# Tasha
# Emmanuel
# Paul
# David
# FavourChristianElon
# Christian

# %%
f = open("Marvel.txt", "a")
f.write("\nElon")
f.close()

# %%
f = open("Marvel.txt")
print(f.read())
# Out:
# Jubal
# Trump
# Tasha
# Emmanuel
# Paul
# David
# FavourChristianElon
# Christian
# Elon

# %%
# try: Runs the risky code that might cause an error
# except: Catches and handles the error if one occurs.
# else: Executes only if no exception occurs in try.
# finally: Runs regarless of what happens useful for cleanup task like closing files.

# %%
filename = 'alice.txt'
try:
    f = open(filename, 'r')
except FileNotFoundError:
    print('The file was not found')
# Out:
# The file was not found

# %%
try:
    print(name)
except NameError:
    print('name not defined')
# Out:
# name not defined

# %%
try:
    5/0
except ZeroDivisionError:
    print('division by zero not allowed')
# Out:
# division by zero not allowed

# %%
try:
    5/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
while True:
    first_number = input("\nFirst number: ")
    if first_number == 'q':
        break
    second_number = input("Second number: ")
    if second_number == 'q':
        break
    try:
        answer = int(first_number) / int(second_number)
    except ZeroDivisionError:
        print("You can't divide by 0!")
    else:
        print(answer)
# Out:
# First number:  5
# Second number:  6
# 0.8333333333333334
# First number:  4
# Second number:  0
# You can't divide by 0!
# First number:  16
# Second number:  80
# 0.2
# First number:  q

# %%
def read_file():
    try:
        filename = input("Enter the file name: ")
        with open(filename, "r") as file:
            content = file.read()
            print("\nFile Content:\n")
            print(content)
    except FileNotFoundError:
        print("Error: File not found. Please check the file name and try again.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

read_file()
